# %% [markdown]
# # 📘 Semana 1 - Día 6: Recursos Audiovisuales (Opcional)
#
# ---
#
# ## 📋 Metadatos del Curso
#
# - **Nivel:** Introductorio
# - **Tiempo diario:** 20 minutos
# - **Semana:** 1 — Fundamentos de Blockchain
# - **Día:** 6 (Opcional - Recursos complementarios)
#
# ---
#
# ## 🎯 Objetivo del Día
#
# Este día opcional está diseñado para:
# - Reforzar conceptos mediante contenido audiovisual
# - Proporcionar perspectivas adicionales de expertos en la industria
# - Ofrecer recursos para aprendizaje autónomo y profundización
#
# **Nota:** Los enlaces y recursos deben ser verificados por el instructor antes de compartir con estudiantes, ya que el contenido web puede cambiar o volverse obsoleto.
#
# ---

# %% [markdown]
# ## 🎥 Videos Recomendados
#
# ### 1. Introducción a Blockchain (Conceptos Básicos)
#
# **Título sugerido:** "How does a blockchain work - Simply Explained"
# **Autor/Canal:** Simply Explained
# **Duración aproximada:** 5-7 minutos
# **Idioma:** Inglés (buscar versiones con subtítulos en español)
# **Temas cubiertos:**
# - Qué es un bloque
# - Cómo se encadenan los bloques
# - Concepto de descentralización
# - Visualización animada del proceso
#
# **Búsqueda recomendada:** "blockchain simply explained" en YouTube
#
# ---
#
# ### 2. Funciones Hash Explicadas
#
# **Título sugerido:** "SHA: Secure Hashing Algorithm - Computerphile"
# **Autor/Canal:** Computerphile
# **Duración aproximada:** 10-15 minutos
# **Idioma:** Inglés
# **Temas cubiertos:**
# - Cómo funcionan las funciones hash
# - Propiedades de SHA-256
# - Aplicaciones en seguridad
# - Demostración práctica
#
# **Búsqueda recomendada:** "SHA256 computerphile" en YouTube
#
# ---
#
# ### 3. Bitcoin y Blockchain (Contexto Histórico)
#
# **Título sugerido:** "But how does bitcoin actually work?"
# **Autor/Canal:** 3Blue1Brown
# **Duración aproximada:** 26 minutos
# **Idioma:** Inglés (subtítulos disponibles)
# **Temas cubiertos:**
# - Historia de Bitcoin
# - Proof of Work explicado matemáticamente
# - Firmas digitales
# - Visualizaciones matemáticas elegantes
#
# **Búsqueda recomendada:** "3blue1brown bitcoin" en YouTube
#
# **⚠️ Nota:** Este video es más avanzado. Recomendado para estudiantes que quieran profundizar.
#
# ---
#
# ### 4. Blockchain en Español
#
# **Título sugerido:** "¿Qué es Blockchain? La tecnología detrás de Bitcoin"
# **Búsqueda recomendada:** "blockchain explicado español" en YouTube
# **Duración aproximada:** 5-10 minutos
# **Temas cubiertos:**
# - Explicación en español de conceptos básicos
# - Casos de uso
# - Ventajas y desventajas
#
# **Canales recomendados en español:**
# - Platzi
# - Código Facilito
# - DotCSV (para aspectos técnicos)
#
# ---

# %% [markdown]
# ## 📄 Artículos y Lecturas Recomendadas
#
# ### 1. Whitepaper Original de Bitcoin
#
# **Título:** "Bitcoin: A Peer-to-Peer Electronic Cash System"
# **Autor:** Satoshi Nakamoto
# **Año:** 2008
# **Páginas:** 9
# **Disponible en:** bitcoin.org/bitcoin.pdf
#
# **Por qué leerlo:**
# - Documento fundacional de blockchain
# - Explica el problema del doble gasto
# - Introduce Proof of Work
# - Escrito de forma accesible (no requiere PhD en criptografía)
#
# **Versión en español:** Buscar "bitcoin whitepaper español" (varias traducciones disponibles)
#
# ---
#
# ### 2. Artículo Introductorio
#
# **Título sugerido:** "Blockchain Technology Explained: The Ultimate Beginner's Guide"
# **Fuente:** Blogs técnicos como Medium, freeCodeCamp, o Hackernoon
# **Búsqueda recomendada:** "blockchain beginner guide medium"
#
# **Temas típicamente cubiertos:**
# - Historia y evolución
# - Casos de uso más allá de criptomonedas
# - Limitaciones y desafíos
# - Futuro de la tecnología
#
# ---
#
# ### 3. Documentación Técnica
#
# **Python hashlib Documentation**
# **URL:** docs.python.org/3/library/hashlib.html
# **Utilidad:** Referencia oficial para funciones hash en Python
#
# **JSON en Python**
# **URL:** docs.python.org/3/library/json.html
# **Utilidad:** Entender serialización de datos para hashing
#
# ---

# %% [markdown]
# ## 🛠️ Herramientas Interactivas
#
# ### 1. Blockchain Demo (Anders Brownworth)
#
# **URL:** andersbrownworth.com/blockchain
# **Descripción:** Simulador interactivo de blockchain en el navegador
# **Características:**
# - Visualización de bloques en tiempo real
# - Demostración de minería (Proof of Work)
# - Simulación de red distribuida
# - Detección de alteraciones
#
# **Actividad sugerida:**
# 1. Crear varios bloques
# 2. Alterar un bloque antiguo
# 3. Observar cómo se rompe la cadena
# 4. Experimentar con diferentes niveles de dificultad de minería
#
# ---
#
# ### 2. SHA-256 Hash Generator
#
# **Búsqueda:** "SHA256 online generator"
# **Descripción:** Herramientas web para generar hashes SHA-256
# **Uso educativo:**
# - Experimentar con diferentes entradas
# - Observar el efecto avalancha
# - Comparar hashes de textos similares
#
# **Sitios recomendados:**
# - emn178.github.io/online-tools/sha256.html
# - xorbin.com/tools/sha256-hash-calculator
#
# ---
#
# ### 3. Exploradores de Blockchain Reales
#
# **Bitcoin:**
# - blockchain.com/explorer
# - blockchair.com
#
# **Ethereum:**
# - etherscan.io
#
# **Actividad sugerida:**
# 1. Explorar bloques recientes
# 2. Observar la estructura real de bloques
# 3. Ver transacciones en tiempo real
# 4. Comparar con lo aprendido en el curso
#
# ---

# %% [markdown]
# ## 📚 Libros Recomendados (Para Profundizar)
#
# ### 1. "Mastering Bitcoin" - Andreas M. Antonopoulos
#
# **Nivel:** Intermedio-Avanzado
# **Idioma:** Inglés (traducción al español disponible)
# **Disponibilidad:** Versión digital gratuita en GitHub
# **Temas:**
# - Arquitectura técnica de Bitcoin
# - Criptografía aplicada
# - Desarrollo de aplicaciones
#
# ---
#
# ### 2. "Blockchain Basics" - Daniel Drescher
#
# **Nivel:** Principiante
# **Idioma:** Inglés
# **Enfoque:** Explicaciones no técnicas con analogías
# **Ideal para:** Estudiantes sin background técnico fuerte
#
# ---
#
# ### 3. "The Bitcoin Standard" - Saifedean Ammous
#
# **Nivel:** Principiante
# **Enfoque:** Económico e histórico (no técnico)
# **Temas:**
# - Historia del dinero
# - Economía de Bitcoin
# - Implicaciones sociales
#
# ---

# %% [markdown]
# ## 🎓 Cursos Online Complementarios
#
# ### Plataformas en Español
#
# **Platzi:**
# - Curso de Fundamentos de Blockchain
# - Curso de Bitcoin y Criptomonedas
#
# **Coursera:**
# - "Blockchain Basics" (Universidad de Buffalo)
# - Subtítulos en español disponibles
#
# **edX:**
# - "Blockchain Fundamentals" (UC Berkeley)
#
# ### Plataformas en Inglés
#
# **freeCodeCamp:**
# - Tutoriales gratuitos de blockchain
# - Proyectos prácticos
#
# **Udemy:**
# - "Blockchain A-Z" (muy popular)
# - "Ethereum and Solidity: The Complete Developer's Guide"
#
# ---

# %% [markdown]
# ## 🔬 Experimentos Prácticos Adicionales
#
# ### Experimento 1: Comparar Funciones Hash
#
# **Objetivo:** Entender diferencias entre algoritmos hash
# **Actividad:**

# %%
import hashlib

texto = "Blockchain"

# Diferentes algoritmos hash
hash_md5 = hashlib.md5(texto.encode()).hexdigest()
hash_sha1 = hashlib.sha1(texto.encode()).hexdigest()
hash_sha256 = hashlib.sha256(texto.encode()).hexdigest()
hash_sha512 = hashlib.sha512(texto.encode()).hexdigest()

print("Comparación de Algoritmos Hash")
print("=" * 70)
print(f"Texto: {texto}")
print()
print(f"MD5    ({len(hash_md5)} chars):  {hash_md5}")
print(f"SHA1   ({len(hash_sha1)} chars): {hash_sha1}")
print(f"SHA256 ({len(hash_sha256)} chars): {hash_sha256}")
print(f"SHA512 ({len(hash_sha512)} chars): {hash_sha512}")
print("=" * 70)
print("\n💡 Observa: Mayor longitud = Mayor seguridad (pero más lento)")
print("   MD5 y SHA1 están obsoletos para seguridad crítica.")
print("   SHA256 es el estándar actual en blockchain.")

# %% [markdown]
# ### Experimento 2: Medir Velocidad de Hashing

# %%
import hashlib
import time

# Generar un texto grande
texto_grande = "Blockchain " * 100000  # 1.1 MB aproximadamente

# Medir tiempo de hashing
inicio = time.time()
hash_resultado = hashlib.sha256(texto_grande.encode()).hexdigest()
fin = time.time()

tiempo_transcurrido = (fin - inicio) * 1000  # Convertir a milisegundos

print("Prueba de Velocidad de Hashing")
print("=" * 70)
print(f"Tamaño del texto: {len(texto_grande):,} caracteres")
print(f"Tiempo de hashing: {tiempo_transcurrido:.2f} ms")
print(f"Hash resultante: {hash_resultado[:32]}...")
print("=" * 70)
print("\n💡 Conclusión: SHA-256 es extremadamente rápido,")
print("   incluso para grandes cantidades de datos.")

# %% [markdown]
# ---
#
# ## ✅ Checklist de Aprendizaje
#
# Marca los recursos que has explorado:
#
# ### Videos
# - [ ] Video introductorio sobre blockchain
# - [ ] Video sobre funciones hash
# - [ ] Video sobre Bitcoin (opcional, avanzado)
# - [ ] Video en español sobre blockchain
#
# ### Lecturas
# - [ ] Whitepaper de Bitcoin (al menos resumen)
# - [ ] Artículo introductorio sobre blockchain
# - [ ] Documentación de hashlib en Python
#
# ### Herramientas Interactivas
# - [ ] Blockchain Demo de Anders Brownworth
# - [ ] Generador de hash SHA-256 online
# - [ ] Explorador de blockchain real (Bitcoin o Ethereum)
#
# ### Experimentos
# - [ ] Comparar diferentes algoritmos hash
# - [ ] Medir velocidad de hashing
#
# ---

# %% [markdown]
# ## 🎯 Reflexión Final
#
# Después de explorar estos recursos, reflexiona sobre:
#
# 1. **¿Qué recurso te resultó más útil y por qué?**
#
# 2. **¿Qué concepto que no entendías completamente ahora tiene más sentido?**
#
# 3. **¿Qué preguntas nuevas surgieron después de explorar estos materiales?**
#
# 4. **¿Cómo podrías aplicar blockchain en tu campo de interés?**
#
# ---
#
# ## 📝 Notas para el Instructor
#
# **Importante:**
# - Verificar todos los enlaces antes de compartir con estudiantes
# - Actualizar recursos regularmente (el contenido web cambia)
# - Considerar crear una lista de reproducción curada en YouTube
# - Adaptar recursos según el nivel del grupo
# - Fomentar discusión sobre los videos/artículos en clase
#
# **Sugerencias de uso:**
# - Asignar 1-2 recursos como tarea para la semana
# - Crear foro de discusión sobre los materiales
# - Pedir a estudiantes que presenten un recurso que encontraron útil
# - Usar los experimentos de código como actividades en clase
#
# ---
#
# **¡Disfruta explorando el mundo de blockchain! 🚀**
#
# *El aprendizaje no termina aquí. Estos recursos son solo el comienzo de tu viaje en blockchain y tecnologías descentralizadas.*
